# %%
import numpy as np

# %%
x = np.array([3, 4, -10])
print(x)
# Out:
# [  3   4 -10]

# %%
for i in range(1,100):
    x = x + np.array([0.1, 0.1, 0.1])
    print(i, np.sum(x))
# Out:
# 1 -2.700000000000001
# 2 -2.4000000000000012
# 3 -2.1000000000000014
# 4 -1.8000000000000025
# 5 -1.5000000000000036
# 6 -1.2000000000000028
# 7 -0.9000000000000039
# 8 -0.600000000000005
# 9 -0.30000000000000604
# 10 -7.105427357601002e-15
# 11 0.29999999999999183
# 12 0.5999999999999908
# 13 0.8999999999999897
# 14 1.1999999999999886
# 15 1.4999999999999876
# 16 1.7999999999999865
# 17 2.0999999999999854
# 18 2.3999999999999844
# 19 2.6999999999999833
# 20 2.9999999999999822
# 21 3.299999999999981
# 22 3.59999999999998
# 23 3.899999999999979
# 24 4.199999999999978
# 25 4.499999999999977
# 26 4.799999999999976
# 27 5.099999999999975
# 28 5.399999999999974
# 29 5.699999999999973
# 30 5.999999999999972
# 31 6.2999999999999705
# 32 6.5999999999999694
# 33 6.899999999999968
# 34 7.199999999999967
# 35 7.499999999999966
# 36 7.799999999999965
# 37 8.099999999999964
# 38 8.399999999999963
# 39 8.699999999999962
# 40 8.999999999999961
# 41 9.29999999999996
# 42 9.599999999999959
# ...
